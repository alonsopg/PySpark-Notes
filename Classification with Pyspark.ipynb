# %% [markdown]
# # Clasification with PySpark
#
# Los modelos de clasificación pueden usarse para resolver distintos problemas:
#
#  * Predecir la probabilidad de que un usuario seleccione un anuncio de internet (selecciona o no selecciona)
#  * Detectar fraude (fraude o no fraude)
#  * clasificar imagenes en categorias, clases o etiquetas (multiclase)
#  * Asignar categorias a articulos de noticias, paginas de internet y opiniones.
#
#  Para este ejemplo usaremos el [Kaggle StumpleUpon evergreen dataset](https://www.kaggle.com/c/stumbleupon/data)

# %%
path = "/Users/user/GitHub/PySpark-Notes/StumpleUponEvergreen/train.tsv"
raw_data = sc.textFile(path)
num_data = raw_data.count()
records = raw_data.map(lambda x: x.split('\t"'))
first = records.first()
print first
# Out:
# [u'"url"', u'urlid"', u'boilerplate"', u'alchemy_category"', u'alchemy_category_score"', u'avglinksize"', u'commonlinkratio_1"', u'commonlinkratio_2"', u'commonlinkratio_3"', u'commonlinkratio_4"', u'compression_ratio"', u'embed_ratio"', u'framebased"', u'frameTagRatio"', u'hasDomainLink"', u'html_ratio"', u'image_ratio"', u'is_news"', u'lengthyLinkDomain"', u'linkwordscore"', u'news_front_page"', u'non_markup_alphanum_characters"', u'numberOfLinks"', u'numwords_in_url"', u'parametrizedLinkRatio"', u'spelling_errors_ratio"', u'label"']

# %%
text_file = sc.textFile('/Users/user/GitHub/PySpark-Notes/StumpleUponEvergreen/train.tsv')
text_file.collect()
# Out:
# [u'"url"\t"urlid"\t"boilerplate"\t"alchemy_category"\t"alchemy_category_score"\t"avglinksize"\t"commonlinkratio_1"\t"commonlinkratio_2"\t"commonlinkratio_3"\t"commonlinkratio_4"\t"compression_ratio"\t"embed_ratio"\t"framebased"\t"frameTagRatio"\t"hasDomainLink"\t"html_ratio"\t"image_ratio"\t"is_news"\t"lengthyLinkDomain"\t"linkwordscore"\t"news_front_page"\t"non_markup_alphanum_characters"\t"numberOfLinks"\t"numwords_in_url"\t"parametrizedLinkRatio"\t"spelling_errors_ratio"\t"label"',
# ...
